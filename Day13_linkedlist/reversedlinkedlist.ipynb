# %% [markdown]
# Given the head of a singly linked list, reverse the list, and return the reversed list.
#
#
#
# Example 1:
#
#
# Input: head = [1,2,3,4,5]
# Output: [5,4,3,2,1]
# Example 2:
#
#
# Input: head = [1,2]
# Output: [2,1]
# Example 3:
#
# Input: head = []
# Output: []
#
#
# Constraints:
#
# The number of nodes in the list is the range [0, 5000].
# -5000 <= Node.val <= 5000
#
#
# Follow up: A linked list can be reversed either iteratively or recursively. Could you implement both?

# %%
from typing import Optional

class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

class Solution:
    def reverseList(self, head: Optional[ListNode]) -> Optional[ListNode]:
        prev = None
        current = head
        
        while current:
            next_node = current.next
            current.next = prev
            prev = current
            current = next_node
        
        return prev
    
    def reverseListRecursive(self, head: Optional[ListNode]) -> Optional[ListNode]:
        if not head or not head.next:
            return head
        
        reversed_head = self.reverseListRecursive(head.next)
        head.next.next = head
        head.next = None
        
        return reversed_head

# %%
# Debug version with prints
class SolutionDebug:
    def reverseListDebug(self, head: Optional[ListNode]) -> Optional[ListNode]:
        print("=== ITERATIVE REVERSE ===")
        prev = None
        current = head
        step = 0
        
        while current:
            print(f"\nStep {step}:")
            print(f"  current: val={current.val}, id={id(current)}")
            print(f"  prev: {f'val={prev.val}, id={id(prev)}' if prev else 'None'}")
            
            next_node = current.next
            print(f"  next_node: {f'val={next_node.val}, id={id(next_node)}' if next_node else 'None'}")
            
            current.next = prev
            print(f"  Reversed link: {current.val} -> {prev.val if prev else 'None'}")
            
            prev = current
            current = next_node
            step += 1
        
        print(f"\nFinal: prev (new head) = {f'val={prev.val}, id={id(prev)}' if prev else 'None'}")
        return prev
    
    def reverseListRecursiveDebug(self, head: Optional[ListNode], depth=0) -> Optional[ListNode]:
        indent = "  " * depth
        print(f"{indent}Call depth {depth}: head={f'val={head.val}, id={id(head)}' if head else 'None'}")
        
        if not head or not head.next:
            print(f"{indent}Base case reached, returning {f'val={head.val}' if head else 'None'}")
            return head
        
        print(f"{indent}Recursing on next node (val={head.next.val})")
        reversed_head = self.reverseListRecursiveDebug(head.next, depth + 1)
        
        print(f"{indent}Back at depth {depth}: Reversing {head.next.val} -> {head.val}")
        head.next.next = head
        head.next = None
        
        return reversed_head

# %%
def create_list(arr):
    if not arr:
        return None
    head = ListNode(arr[0])
    current = head
    for val in arr[1:]:
        current.next = ListNode(val)
        current = current.next
    return head

def list_to_array(head):
    result = []
    while head:
        result.append(head.val)
        head = head.next
    return result

# Test iterative with debug
sol_debug = SolutionDebug()
head1 = create_list([1,2,3])
result1 = sol_debug.reverseListDebug(head1)
print(f"\nResult: {list_to_array(result1)}\n")

# Test recursive with debug
print("\n=== RECURSIVE REVERSE ===")
head2 = create_list([1,2,3])
result2 = sol_debug.reverseListRecursiveDebug(head2)
print(f"\nResult: {list_to_array(result2)}")
# Out:
# === ITERATIVE REVERSE ===
#
# Step 0:
#   current: val=1, id=2084313064848
#   prev: None
#   next_node: val=2, id=2084313359952
#   Reversed link: 1 -> None
#
# Step 1:
#   current: val=2, id=2084313359952
#   prev: val=1, id=2084313064848
#   next_node: val=3, id=2084313358864
#   Reversed link: 2 -> 1
#
# Step 2:
#   current: val=3, id=2084313358864
#   prev: val=2, id=2084313359952
#   next_node: None
#   Reversed link: 3 -> 2
#
# Final: prev (new head) = val=3, id=2084313358864
#
# Result: [3, 2, 1]
#
#
# === RECURSIVE REVERSE ===
# Call depth 0: head=val=1, id=2084312900240
# Recursing on next node (val=2)
#   Call depth 1: head=val=2, id=2084313359120
#   Recursing on next node (val=3)
#     Call depth 2: head=val=3, id=2084313112336
#     Base case reached, returning val=3
#   Back at depth 1: Reversing 3 -> 2
# Back at depth 0: Reversing 2 -> 1
#
# Result: [3, 2, 1]

# %%
# Regular tests
sol = Solution()

head1 = create_list([1,2,3,4,5])
print(list_to_array(sol.reverseList(head1)))

head2 = create_list([1,2])
print(list_to_array(sol.reverseListRecursive(head2)))

head3 = create_list([])
print(list_to_array(sol.reverseList(head3)))
# Out:
# [5, 4, 3, 2, 1]
# [2, 1]
# []

# %%
# This code appears to be JavaScript, not Python. Here's the Python equivalent:

class Node:
    def __init__(self, new_data):
        self.data = new_data
        self.next = None

def reverse_list(head):
    stack = []
    temp = head
    
    # push all nodes into stack
    while temp is not None:
        stack.append(temp)
        temp = temp.next
    
    # make the last node as new head of the linked list
    if len(stack) > 0:
        head = stack.pop()
        temp = head
        
        # pop all the nodes and append to the linked list
        while len(stack) > 0:
            temp.next = stack.pop()
            temp = temp.next
        
        temp.next = None
    
    return head

def print_list(node):
    result = []
    while node is not None:
        result.append(str(node.data))
        node = node.next
    print(" -> ".join(result))

# driver code
head = Node(1)
head.next = Node(2)
head.next.next = Node(3)
head.next.next.next = Node(4)
head.next.next.next.next = Node(5)

head = reverse_list(head)
print_list(head)

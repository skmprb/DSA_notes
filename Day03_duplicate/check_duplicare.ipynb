# %%
# works only for the positive numbers not for the negative numbers

def contains_duplicate(nums):
    for num in nums:
        if num in nums[nums.index(num) + 1:]:
            return True
        
    return False

print(contains_duplicate([1, 2, 3,1]))
# Out:
# True

# %%
def contains_duplicate(nums):
    seen = set()
    for num in nums:
        if num in seen:
            return True
        seen.add(num)
        
    return False

contains_duplicate([1, 2, 3,1])
# Out:
# True

# %%
def contains_duplicate(nums):
    nums = sorted(nums)
    for i in range(len(nums)-1):
        if nums[i] == nums[i+1]:
            return True
        
    return False

contains_duplicate([1, 2, 3,1])
# Out:
# True

# %%
def contains_duplicate(nums):
    return len(nums) != len(set(nums))

contains_duplicate([1, 2, 3,1])
# Out:
# True

# %%
class solution:
    def contains_duplicate(self,nums) -> bool:
        return len(nums)!=len(set(nums))
    
s = solution()
print(s.contains_duplicate([1,2,3,4,5,1]))
# Out:
# True

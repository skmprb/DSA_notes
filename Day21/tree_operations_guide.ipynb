# %% [markdown]
# # Binary Tree Operations - Complete Guide
#
# This notebook covers all essential binary tree operations including:
# - Tree structure and node definition
# - Accessing left and right nodes
# - Building trees
# - Tree traversals (Inorder, Preorder, Postorder, Level Order)
# - Inserting nodes
# - Deleting nodes
# - Searching nodes
# - Display and visualization

# %% [markdown]
# ## 1. Tree Node Definition

# %%
from typing import Optional
from collections import deque

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

# %% [markdown]
# ## 2. Building a Tree

# %%
# Method 1: Manual construction
root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(3)
root.left.left = TreeNode(4)
root.left.right = TreeNode(5)
root.right.left = TreeNode(6)
root.right.right = TreeNode(7)

# Tree structure:
#       1
#      / \
#     2   3
#    / \ / \
#   4  5 6  7

# %%
# Method 2: Build from array (level order)
def build_tree_from_array(arr):
    if not arr:
        return None
    
    root = TreeNode(arr[0])
    queue = deque([root])
    i = 1
    
    while queue and i < len(arr):
        node = queue.popleft()
        
        if i < len(arr) and arr[i] is not None:
            node.left = TreeNode(arr[i])
            queue.append(node.left)
        i += 1
        
        if i < len(arr) and arr[i] is not None:
            node.right = TreeNode(arr[i])
            queue.append(node.right)
        i += 1
    
    return root

# Example
tree = build_tree_from_array([1, 2, 3, 4, 5, 6, 7])
print("Tree built from array")

# %% [markdown]
# ## 3. Accessing Nodes

# %%
# Access left and right nodes
print(f"Root value: {root.val}")
print(f"Left child: {root.left.val if root.left else None}")
print(f"Right child: {root.right.val if root.right else None}")
print(f"Left-Left grandchild: {root.left.left.val if root.left and root.left.left else None}")
print(f"Right-Right grandchild: {root.right.right.val if root.right and root.right.right else None}")

# %% [markdown]
# ## 4. Tree Traversals

# %%
# Inorder Traversal (Left -> Root -> Right)
def inorder(root):
    result = []
    def traverse(node):
        if not node:
            return
        traverse(node.left)
        result.append(node.val)
        traverse(node.right)
    traverse(root)
    return result

print(f"Inorder: {inorder(root)}")

# %%
# Preorder Traversal (Root -> Left -> Right)
def preorder(root):
    result = []
    def traverse(node):
        if not node:
            return
        result.append(node.val)
        traverse(node.left)
        traverse(node.right)
    traverse(root)
    return result

print(f"Preorder: {preorder(root)}")

# %%
# Postorder Traversal (Left -> Right -> Root)
def postorder(root):
    result = []
    def traverse(node):
        if not node:
            return
        traverse(node.left)
        traverse(node.right)
        result.append(node.val)
    traverse(root)
    return result

print(f"Postorder: {postorder(root)}")

# %%
# Level Order Traversal (BFS)
def level_order(root):
    if not root:
        return []
    result = []
    queue = deque([root])
    
    while queue:
        node = queue.popleft()
        result.append(node.val)
        if node.left:
            queue.append(node.left)
        if node.right:
            queue.append(node.right)
    
    return result

print(f"Level Order: {level_order(root)}")

# %%
# Level Order by Levels (each level in separate list)
def level_order_by_levels(root):
    if not root:
        return []
    result = []
    queue = deque([root])
    
    while queue:
        level_size = len(queue)
        level = []
        for _ in range(level_size):
            node = queue.popleft()
            level.append(node.val)
            if node.left:
                queue.append(node.left)
            if node.right:
                queue.append(node.right)
        result.append(level)
    
    return result

print(f"Level Order by Levels: {level_order_by_levels(root)}")

# %% [markdown]
# ## 5. Display/Print Tree

# %%
# Simple tree display
def print_tree(root, level=0, prefix="Root: "):
    if root is not None:
        print(" " * (level * 4) + prefix + str(root.val))
        if root.left or root.right:
            if root.left:
                print_tree(root.left, level + 1, "L--- ")
            else:
                print(" " * ((level + 1) * 4) + "L--- None")
            if root.right:
                print_tree(root.right, level + 1, "R--- ")
            else:
                print(" " * ((level + 1) * 4) + "R--- None")

print("Tree Structure:")
print_tree(root)

# %% [markdown]
# ## 6. Inserting Nodes

# %%
# Insert in BST (Binary Search Tree)
def insert_bst(root, val):
    if not root:
        return TreeNode(val)
    
    if val < root.val:
        root.left = insert_bst(root.left, val)
    else:
        root.right = insert_bst(root.right, val)
    
    return root

# Create BST
bst = TreeNode(5)
bst = insert_bst(bst, 3)
bst = insert_bst(bst, 7)
bst = insert_bst(bst, 1)
bst = insert_bst(bst, 4)
bst = insert_bst(bst, 6)
bst = insert_bst(bst, 9)

print("BST Inorder (sorted):", inorder(bst))
print_tree(bst)

# %%
# Insert at first available position (level order)
def insert_level_order(root, val):
    if not root:
        return TreeNode(val)
    
    queue = deque([root])
    while queue:
        node = queue.popleft()
        
        if not node.left:
            node.left = TreeNode(val)
            return root
        else:
            queue.append(node.left)
        
        if not node.right:
            node.right = TreeNode(val)
            return root
        else:
            queue.append(node.right)
    
    return root

# Test
test_tree = TreeNode(1)
insert_level_order(test_tree, 2)
insert_level_order(test_tree, 3)
insert_level_order(test_tree, 4)
print("After insertions:", level_order(test_tree))

# %% [markdown]
# ## 7. Searching Nodes

# %%
# Search in any binary tree
def search(root, val):
    if not root:
        return False
    if root.val == val:
        return True
    return search(root.left, val) or search(root.right, val)

print(f"Search 5 in tree: {search(root, 5)}")
print(f"Search 10 in tree: {search(root, 10)}")

# %%
# Search in BST (more efficient)
def search_bst(root, val):
    if not root:
        return False
    if root.val == val:
        return True
    if val < root.val:
        return search_bst(root.left, val)
    return search_bst(root.right, val)

print(f"Search 4 in BST: {search_bst(bst, 4)}")
print(f"Search 10 in BST: {search_bst(bst, 10)}")

# %% [markdown]
# ## 8. Deleting Nodes

# %%
# Delete node in BST
def delete_bst(root, val):
    if not root:
        return None
    
    if val < root.val:
        root.left = delete_bst(root.left, val)
    elif val > root.val:
        root.right = delete_bst(root.right, val)
    else:
        # Node found - 3 cases
        # Case 1: No children
        if not root.left and not root.right:
            return None
        
        # Case 2: One child
        if not root.left:
            return root.right
        if not root.right:
            return root.left
        
        # Case 3: Two children - find inorder successor (min in right subtree)
        min_node = root.right
        while min_node.left:
            min_node = min_node.left
        root.val = min_node.val
        root.right = delete_bst(root.right, min_node.val)
    
    return root

# Test deletion
print("Before deletion:", inorder(bst))
bst = delete_bst(bst, 3)
print("After deleting 3:", inorder(bst))

# %%
# Delete deepest rightmost node (for general binary tree)
def delete_deepest(root, d_node):
    queue = deque([root])
    while queue:
        node = queue.popleft()
        if node is d_node:
            node = None
            return
        if node.right:
            if node.right is d_node:
                node.right = None
                return
            else:
                queue.append(node.right)
        if node.left:
            if node.left is d_node:
                node.left = None
                return
            else:
                queue.append(node.left)

def delete_node(root, val):
    if not root:
        return None
    if not root.left and not root.right:
        if root.val == val:
            return None
        return root
    
    queue = deque([root])
    key_node = None
    last_node = None
    
    while queue:
        last_node = queue.popleft()
        if last_node.val == val:
            key_node = last_node
        if last_node.left:
            queue.append(last_node.left)
        if last_node.right:
            queue.append(last_node.right)
    
    if key_node:
        key_node.val = last_node.val
        delete_deepest(root, last_node)
    return root

print("General tree deletion example")

# %% [markdown]
# ## 9. Common Tree Properties

# %%
# Height of tree
def height(root):
    if not root:
        return 0
    return 1 + max(height(root.left), height(root.right))

print(f"Tree height: {height(root)}")

# %%
# Count nodes
def count_nodes(root):
    if not root:
        return 0
    return 1 + count_nodes(root.left) + count_nodes(root.right)

print(f"Total nodes: {count_nodes(root)}")

# %%
# Count leaf nodes
def count_leaves(root):
    if not root:
        return 0
    if not root.left and not root.right:
        return 1
    return count_leaves(root.left) + count_leaves(root.right)

print(f"Leaf nodes: {count_leaves(root)}")

# %%
# Find maximum value
def find_max(root):
    if not root:
        return float('-inf')
    return max(root.val, find_max(root.left), find_max(root.right))

print(f"Maximum value: {find_max(root)}")

# %%
# Find minimum value
def find_min(root):
    if not root:
        return float('inf')
    return min(root.val, find_min(root.left), find_min(root.right))

print(f"Minimum value: {find_min(root)}")

# %% [markdown]
# ## 10. Complete Example - All Operations

# %%
# Create a sample tree
sample = build_tree_from_array([10, 5, 15, 3, 7, 12, 20])

print("=== Tree Structure ===")
print_tree(sample)

print("\n=== Traversals ===")
print(f"Inorder: {inorder(sample)}")
print(f"Preorder: {preorder(sample)}")
print(f"Postorder: {postorder(sample)}")
print(f"Level Order: {level_order(sample)}")

print("\n=== Properties ===")
print(f"Height: {height(sample)}")
print(f"Total Nodes: {count_nodes(sample)}")
print(f"Leaf Nodes: {count_leaves(sample)}")
print(f"Max Value: {find_max(sample)}")
print(f"Min Value: {find_min(sample)}")

print("\n=== Search ===")
print(f"Search 7: {search(sample, 7)}")
print(f"Search 100: {search(sample, 100)}")

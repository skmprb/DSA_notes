# %% [markdown]
# Given an array of strings strs, group the anagrams together. You can return the answer in any order.
#
#
#
# Example 1:
#
# Input: strs = ["eat","tea","tan","ate","nat","bat"]
#
# Output: [["bat"],["nat","tan"],["ate","eat","tea"]]
#
# Explanation:
#
# There is no string in strs that can be rearranged to form "bat".
# The strings "nat" and "tan" are anagrams as they can be rearranged to form each other.
# The strings "ate", "eat", and "tea" are anagrams as they can be rearranged to form each other.
# Example 2:
#
# Input: strs = [""]
#
# Output: [[""]]
#
# Example 3:
#
# Input: strs = ["a"]
#
# Output: [["a"]]
#
#
#
# Constraints:
#
# 1 <= strs.length <= 104
# 0 <= strs[i].length <= 100
# strs[i] consists of lowercase English letters.

# %%
from collections import Counter
def groupAnagram(list):
    res = []
    group = {}

    for i in range(len(list)-1):
        temp = []
        for j in range(i, len(list)):
            if Counter(list[i]) == Counter(list[j]):
                temp.append(list[j])
        res.append(temp)
    return res
    
print(groupAnagram(["eat","tea","tan","ate","nat","bat"]))
# Out:
# [['eat', 'tea', 'ate'], ['tea', 'ate'], ['tan', 'nat'], ['ate'], ['nat']]

# %%
from collections import Counter
def groupAnagram(list):
    res = []
    used = set()

    for i in range(len(list)):
        if list[i] in used:
            continue
        temp = []
        for j in range(i, len(list)):
            if Counter(list[i]) == Counter(list[j]):
                temp.append(list[j])
                used.add(list[j])
        res.append(temp)
    return res
    
print(groupAnagram(["eat","tea","tan","ate","nat","bat"]))
# Out:
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]

# %%
def groupAnagram(list):
    res = []
    used = set()
    anagram = {}

    for i in range(len(list)):
        sorted_str = ''.join(sorted(list[i]))
        if sorted_str in anagram:
            anagram[sorted_str].append(list[i])
        else:
            anagram[sorted_str] = [list[i]]

    for i in anagram.values():
        res.append(i)

    return res

# %%
from collections import defaultdict

def groupAnagram(strs):
    group = defaultdict(list)
    print(group)
    for word in strs:
        key = ''.join(sorted(word))
        print(f"key:{key}")
        group[key].append(word)
        print(f"group:{group}")
    return list(group.values())

print(groupAnagram(["eat", "tea", "tan", "ate", "nat", "bat"]))
# Out:
# defaultdict(<class 'list'>, {})
# key:aet
# group:defaultdict(<class 'list'>, {'aet': ['eat']})
# key:aet
# group:defaultdict(<class 'list'>, {'aet': ['eat', 'tea']})
# key:ant
# group:defaultdict(<class 'list'>, {'aet': ['eat', 'tea'], 'ant': ['tan']})
# key:aet
# group:defaultdict(<class 'list'>, {'aet': ['eat', 'tea', 'ate'], 'ant': ['tan']})
# key:ant
# group:defaultdict(<class 'list'>, {'aet': ['eat', 'tea', 'ate'], 'ant': ['tan', 'nat']})
# key:abt
# group:defaultdict(<class 'list'>, {'aet': ['eat', 'tea', 'ate'], 'ant': ['tan', 'nat'], 'abt': ['bat']})
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]

# %%
from typing import List
class Solution:
    def groupAnagrams(self, strs: List[str]) -> List[List[str]]:
        ana_hash = {}
        for w in strs:
            k = "".join(sorted(w))
            if k in ana_hash:
                ana_hash[k].append(w)
            else:
                ana_hash[k] =[w]
        return list(ana_hash.values())

# %%
# class Solution:
#     def groupAnagrams(self, strs: List[str]) -> List[List[str]]:
#         dic = {}
#         preOutput =[]
#         letters='abcdefghijklmnopqrstuvwxyz'
#         for i in letters:
#             dic[i]=0
#         for i in strs:
#             for j in i:
#                 if j in dic:
#                     dic[j]+=1
#             preOutput.append(dic.copy())
#             for i in letters:
#                 dic[i]=0
#         # print(preOutput)
#         final = []
#         while len(preOutput):
#             current = preOutput.pop()
#             word = strs.pop()
#             tmpGroup =[word]
#             while current in preOutput:
#                 index = preOutput.index(current)

#                 preOutput.remove(current)

#                 word = strs.pop(index)

#                 tmpGroup.append(word)
#             final.append(tmpGroup)
#         # final.sort()
#         print(final)
#         return final
                
   
class Solution:
    def groupAnagrams(self, strs: List[str]) -> List[List[str]]:
        groups = {}

        for word in strs:
            count = [0]*26

            for ch in word:
                index = ord(ch)-ord('a')
                count[index] += 1
            
            key = tuple(count)

            if key in groups:
                groups[key].append(word)
            else:
                groups[key] = [word]

        return list(groups.values())
__import__("atexit").register(lambda: open("display_runtime.txt", "w").write("1"))
# Out:
# <function __main__.<lambda>()>

# %%
class Solution:
    def groupAnagrams(self,s:List[str])->List[List[str]]:
        r=[]
        f=[0]*len(s)
        for i in range(len(s)):
            if f[i]==1:continue
            t=[s[i]]
            f[i]=1
            for j in range(i+1,len(s)):
                if f[j]==0 and len(s[i])==len(s[j]):
                    for a in s[i]:
                        if s[i].count(a)!=s[j].count(a):
                            break
                    else:
                        t.append(s[j])
                        f[j]=1
            r.append(t)
        return r

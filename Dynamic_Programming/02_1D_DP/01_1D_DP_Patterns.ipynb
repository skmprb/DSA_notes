# %% [markdown]
# # 1D Dynamic Programming Patterns - Interactive Lab
#
# ## Welcome to Lab 5! 👋
#
# Now you'll master the most common DP pattern - **1D DP** where state is a single variable.
#
# ## What You'll Learn:
# - 6 essential 1D DP patterns
# - When to use each pattern
# - How to implement from scratch
# - Space optimization techniques
#
# ## Patterns Covered:
# 1. Simple Recurrence (Fibonacci-like)
# 2. Decision Making (Take or Skip)
# 3. Kadane's Algorithm
# 4. Longest Increasing Subsequence
# 5. Coin Change
# 6. Decode Ways

# %% [markdown]
# ## Pattern 1: Simple Recurrence
#
# ### 📖 Concept
# State depends on previous 1-2 states with simple addition/combination.
#
# **Template:** `dp[i] = dp[i-1] + dp[i-2] + ...`
#
# ### 🎯 Task 1: Tribonacci Number
#
# **Problem:** T(n) = T(n-1) + T(n-2) + T(n-3)
# - T(0) = 0, T(1) = 1, T(2) = 1
#
# **Your Mission:** Implement using tabulation

# %%
# TODO: Implement Tribonacci
def tribonacci(n):
    """
    Steps:
    1. Handle base cases (n == 0, n <= 2)
    2. Create DP array
    3. Initialize first 3 values
    4. Fill array: dp[i] = dp[i-1] + dp[i-2] + dp[i-3]
    5. Return dp[n]
    """
    # YOUR CODE HERE
    pass

print(f"T(10) = {tribonacci(10)}")  # Should be 149

# %%
# TODO: Now optimize space to O(1)
def tribonacci_optimized(n):
    """
    Use only 3 variables: prev3, prev2, prev1
    """
    # YOUR CODE HERE
    pass

print(f"T(25) = {tribonacci_optimized(25)}")  # Should be 1389537

# %%
# ✅ Verify
assert tribonacci(4) == 4
assert tribonacci_optimized(25) == 1389537
print("✅ Pattern 1 mastered!")

# %% [markdown]
# ## Pattern 2: Decision Making (Take or Skip)
#
# ### 📖 Concept
# At each step, decide whether to take current element or skip it.
#
# **Template:** `dp[i] = max(take, skip)`
#
# ### 🎯 Task 2: House Robber
#
# **Problem:** Rob houses, can't rob adjacent. Find maximum money.
#
# **Analysis:**
# - Rob house i: `nums[i] + dp[i-2]`
# - Skip house i: `dp[i-1]`
# - Choose maximum!

# %%
# TODO: Implement House Robber
def rob(nums):
    """
    Steps:
    1. Handle edge cases
    2. Create DP array
    3. dp[0] = nums[0]
    4. dp[1] = max(nums[0], nums[1])
    5. For i from 2 to n:
       dp[i] = max(nums[i] + dp[i-2], dp[i-1])
    6. Return dp[n-1]
    """
    # YOUR CODE HERE
    pass

houses = [2, 7, 9, 3, 1]
print(f"Max money: {rob(houses)}")  # Should be 12

# %%
# TODO: Space optimize to O(1)
def rob_optimized(nums):
    # YOUR CODE HERE
    pass

print(f"Max money (optimized): {rob_optimized([2, 7, 9, 3, 1])}")

# %%
# ✅ Verify
assert rob([1, 2, 3, 1]) == 4
assert rob_optimized([2, 7, 9, 3, 1]) == 12
print("✅ Pattern 2 mastered!")

# %% [markdown]
# ### 🎯 Task 3: Delete and Earn
#
# **Problem:** Delete nums[i], earn nums[i] points. All nums[i]-1 and nums[i]+1 are deleted. Find max points.
#
# **Key Insight:** Convert to House Robber!
# - Count frequency of each number
# - points[i] = i * frequency[i]
# - Now it's House Robber on points array!

# %%
# TODO: Implement Delete and Earn
def delete_and_earn(nums):
    """
    Steps:
    1. Find max number
    2. Create points array of size max_num + 1
    3. For each num in nums: points[num] += num
    4. Apply House Robber on points array!
    """
    # YOUR CODE HERE
    pass

nums = [3, 4, 2]
print(f"Max points: {delete_and_earn(nums)}")  # Should be 6

# %%
# ✅ Verify
assert delete_and_earn([3, 4, 2]) == 6
assert delete_and_earn([2, 2, 3, 3, 3, 4]) == 9
print("✅ You recognized the pattern!")

# %% [markdown]
# ## Pattern 3: Kadane's Algorithm (Maximum Subarray)
#
# ### 📖 Concept
# At each position, decide: extend previous subarray or start new one.
#
# **Template:** `dp[i] = max(nums[i], dp[i-1] + nums[i])`
#
# ### 🎯 Task 4: Maximum Subarray Sum

# %%
# TODO: Implement Kadane's Algorithm
def max_subarray(nums):
    """
    Key insight:
    - max_ending_here = max sum ending at current position
    - max_so_far = global maximum
    
    At each position:
    max_ending_here = max(nums[i], max_ending_here + nums[i])
    max_so_far = max(max_so_far, max_ending_here)
    """
    # YOUR CODE HERE
    pass

nums = [-2, 1, -3, 4, -1, 2, 1, -5, 4]
print(f"Max subarray sum: {max_subarray(nums)}")  # Should be 6

# %%
# ✅ Verify
assert max_subarray([-2, 1, -3, 4, -1, 2, 1, -5, 4]) == 6
assert max_subarray([5, 4, -1, 7, 8]) == 23
print("✅ Kadane's Algorithm mastered!")

# %% [markdown]
# ### 🎯 Task 5: Maximum Product Subarray
#
# **Twist:** Negative numbers can become positive when multiplied!
#
# **Key Insight:** Track both max AND min products

# %%
# TODO: Implement Maximum Product Subarray
def max_product(nums):
    """
    Track max_prod and min_prod
    
    If current number is negative:
        Swap max_prod and min_prod
    
    max_prod = max(nums[i], max_prod * nums[i])
    min_prod = min(nums[i], min_prod * nums[i])
    
    result = max(result, max_prod)
    """
    # YOUR CODE HERE
    pass

nums = [2, 3, -2, 4]
print(f"Max product: {max_product(nums)}")  # Should be 6

# %%
# ✅ Verify
assert max_product([2, 3, -2, 4]) == 6
assert max_product([-2, 0, -1]) == 0
print("✅ Pattern 3 mastered!")

# %% [markdown]
# ## Pattern 4: Longest Increasing Subsequence
#
# ### 📖 Concept
# For each element, check all previous smaller elements.
#
# **Template:** `dp[i] = max(dp[j] + 1) for all j < i where nums[j] < nums[i]`
#
# ### 🎯 Task 6: Implement LIS

# %%
# TODO: Implement LIS
def length_of_LIS(nums):
    """
    Steps:
    1. Create DP array, initialize all with 1
    2. For each i from 1 to n:
       For each j from 0 to i-1:
           If nums[j] < nums[i]:
               dp[i] = max(dp[i], dp[j] + 1)
    3. Return max(dp)
    
    Time: O(n²)
    """
    # YOUR CODE HERE
    pass

nums = [10, 9, 2, 5, 3, 7, 101, 18]
print(f"Length of LIS: {length_of_LIS(nums)}")  # Should be 4

# %%
# ✅ Verify
assert length_of_LIS([10, 9, 2, 5, 3, 7, 101, 18]) == 4
assert length_of_LIS([0, 1, 0, 3, 2, 3]) == 4
print("✅ LIS pattern mastered!")

# %% [markdown]
# ## Pattern 5: Coin Change
#
# ### 📖 Concept
# For each amount, try all coins and take min/count.
#
# ### 🎯 Task 7: Minimum Coins

# %%
# TODO: Implement Coin Change (Min Coins)
def coin_change(coins, amount):
    """
    Steps:
    1. Create DP array, initialize with infinity
    2. dp[0] = 0
    3. For each amount i from 1 to amount:
       For each coin:
           If coin <= i:
               dp[i] = min(dp[i], 1 + dp[i-coin])
    4. Return dp[amount] if not infinity, else -1
    """
    # YOUR CODE HERE
    pass

coins = [1, 2, 5]
print(f"Min coins for 11: {coin_change(coins, 11)}")  # Should be 3

# %% [markdown]
# ### 🎯 Task 8: Count Ways

# %%
# TODO: Implement Coin Change II (Count Ways)
def change(amount, coins):
    """
    Steps:
    1. Create DP array
    2. dp[0] = 1 (one way to make 0)
    3. For each coin:
       For each amount i from coin to amount:
           dp[i] += dp[i-coin]
    4. Return dp[amount]
    
    Note: Iterate coins first to avoid counting duplicates!
    """
    # YOUR CODE HERE
    pass

print(f"Ways to make 5: {change(5, [1, 2, 5])}")  # Should be 4

# %%
# ✅ Verify
assert coin_change([1, 2, 5], 11) == 3
assert change(5, [1, 2, 5]) == 4
print("✅ Coin Change patterns mastered!")

# %% [markdown]
# ## Pattern 6: Decode Ways
#
# ### 📖 Concept
# At each position, can decode 1 digit or 2 digits.
#
# ### 🎯 Task 9: Implement Decode Ways
#
# **Problem:** 'A'=1, 'B'=2, ..., 'Z'=26. Count ways to decode string.

# %%
# TODO: Implement Decode Ways
def num_decodings(s):
    """
    Steps:
    1. Handle edge cases (empty or starts with '0')
    2. Create DP array
    3. dp[0] = 1, dp[1] = 1
    4. For i from 2 to n:
       - If s[i-1] != '0': dp[i] += dp[i-1]
       - If 10 <= int(s[i-2:i]) <= 26: dp[i] += dp[i-2]
    5. Return dp[n]
    """
    # YOUR CODE HERE
    pass

print(f"Ways to decode '226': {num_decodings('226')}")  # Should be 3

# %%
# ✅ Verify
assert num_decodings('12') == 2
assert num_decodings('226') == 3
print("✅ All 1D DP patterns mastered! 🎉")

# %% [markdown]
# ## 🎓 Summary: 1D DP Patterns
#
# | Pattern | Key Idea | Example |
# |---------|----------|----------|
# | Simple Recurrence | dp[i] = f(dp[i-1], dp[i-2]) | Fibonacci, Tribonacci |
# | Take or Skip | max(take, skip) | House Robber |
# | Kadane's | max(extend, start_new) | Max Subarray |
# | LIS | Check all previous smaller | LIS |
# | Coin Change | Try all options | Min Coins |
# | Decode Ways | 1-digit or 2-digit | Decode Ways |
#
# ## 🎉 Congratulations!
#
# You've mastered 1D DP! Next: **Lab 6: 2D DP - Grid Problems**
#
# **Keep practicing! 🚀**
